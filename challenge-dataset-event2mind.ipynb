# %%
import sys
sys.path.append('ext/LAMA')

# %%
from typing import List, Tuple, Union
from pathlib import Path

import pandas as pd
import json
from itertools import chain

# %% [markdown]
# ## Create dataset

# %%
MASK = '[MASK]'

def should_include_emotion(e: str):
    if len(e.split()) != 1:
        return False
    elif e == 'none':
        return False

    return True

def create_dataset(csv_path: Union[str, Path]) -> List[Tuple[str, Tuple[str]]]:
    if isinstance(csv_path, str):
        csv_path = Path(csv_path)

    # Load dataframe
    df = pd.read_csv(csv_path)
    
    # Create personx dataframe
    df = df[['Event', 'Xemotion']].rename(columns={'Event': 'event', 'Xemotion': 'emotion'})
    df = df[df.event.str.contains("PersonX") & ~df.event.str.contains("___")]
    df.emotion = df.emotion.apply(lambda x: json.loads(x))
    
    data = []
    for event, rows in df.groupby('event'):
        masked_sentence = f'{event} and PersonX feels {MASK}.'
        emotions = tuple(set(e for e in chain.from_iterable(rows.emotion) if should_include_emotion(e)))
        if emotions:
            data.append((masked_sentence, emotions))
            
    return df, data

# %%
df, dataset = create_dataset('data/test.csv')

# %%
with open('test.jsonl', 'a') as f:
    for event, emotions in dataset:
        out = {
            'masked_sentences': [event],
            'obj_label': emotions[0],
            'sub_label': 'Squad'
        }
        json.dump(out, f)
        print(file=f)

# %% [markdown]
# ## Evaluate dataset

# %%
from lama.modules import build_model_by_name
from lama.utils import print_sentence_predictions, load_vocab
import lama.options as options
import lama.evaluation_metrics as evaluation_metrics
import argparse

# %%
def evaluate(sentences, model):
    if len(sentences) > 2:
        print("WARNING: only the first two sentences in the text will be considered!")
        sentences = sentences[:2]

    original_log_probs_list, [token_ids], [masked_indices] = model.get_batch_generation([sentences], try_cuda=False)

    index_list = None
    filtered_log_probs_list = original_log_probs_list

    # rank over the subset of the vocab (if defined) for the SINGLE masked tokens
    if masked_indices and len(masked_indices) > 0:
        evaluation_metrics.get_ranking(filtered_log_probs_list[0], masked_indices, model.vocab, index_list=index_list)

    # prediction and perplexity for the whole softmax
    return print_sentence_predictions(original_log_probs_list[0], token_ids, model.vocab, masked_indices=masked_indices)

# %%
parser = options.get_eval_generation_parser()
args = parser.parse_args(['--lm', 'bert'])

model = build_model_by_name('bert', args)
# Out:
# Loading bert model...

# %%
sentences = ['The cat is on the [MASK].', 'This is a cool [MASK].']
for s in sentences:
    x = evaluate([s], model)
# Out:
# | Top10 predictions
# 0       phone               -2.345
# 1       floor               -2.630
# 2       ground              -2.968
# 3       couch               -3.387
# 4       move                -3.649
# 5       roof                -3.651
# 6       way                 -3.718
# 7       run                 -3.757
# 8       bed                 -3.802
# 9       left                -3.965
#
# ----------------------------------------------------------------------------------
# index   token               log_prob    prediction          log_prob    rank@1000
# ----------------------------------------------------------------------------------
# 0       [CLS]               -12.386     .                   -2.570      -1
# 1       The                 -5.547      .                   -0.607      14
# 2       cat                 -0.367      cat                 -0.367      0
# 3       is                  -0.019      is                  -0.019      0
# 4       on                  -0.001      on                  -0.001      0
# 5       the                 -0.002      the                 -0.002      0
# 6       [MASK]              -14.321     phone               -2.345      -1
# 7       .                   -0.002      .                   -0.002      0
# 8       [SEP]               -20.452     .                   -0.001      -1
#
#
# | Perplexity: 2.690
#
#
#
# | Top10 predictions
# 0       place               -1.510
# 1       day                 -3.184
# 2       spot                -3.268
# 3       night               -3.600
# 4       city                -3.918
# 5       area                -4.110
# 6       town                -4.245
# 7       neighborhood        -4.426
# 8       house               -4.495
# 9       one                 -4.560
#
# ----------------------------------------------------------------------------------
# index   token               log_prob    prediction          log_prob    rank@1000
# ----------------------------------------------------------------------------------
# 0       [CLS]               -12.608     .                   -2.605      -1
# 1       This                -7.515      .                   -0.617      64
# 2       is                  -0.029      is                  -0.029      0
# 3       a                   -0.001      a                   -0.001      0
# 4       cool                -0.550      cool                -0.550      0
# 5       [MASK]              -16.127     place               -1.510      -1
# 6       .                   -0.001      .                   -0.001      0
# 7       [SEP]               -21.439     .                   -0.000      -1
#
#
# | Perplexity: 5.049

# %%
for i, (event, emotions) in enumerate(dataset):
    print("EVENT:", event)
    print("GOLD:", emotions)
    evaluate([event], model)
    print("*********************************")
    
    if i == 10:
        break
# Out:
# EVENT: PersonX accidentally burned and PersonX feels [MASK].
# GOLD: ('painfull', 'scared', 'embarassed', 'angry')
#
# | Top10 predictions
# 0       guilty              -2.584
# 1       sick                -3.396
# 2       trapped             -3.481
# 3       dizzy               -3.562
# 4       bad                 -3.596
# 5       ill                 -3.802
# 6       better              -3.846
# 7       embarrassed         -4.138
# 8       worse               -4.162
# 9       weak                -4.183
#
# ----------------------------------------------------------------------------------
# index   token               log_prob    prediction          log_prob    rank@1000
# ----------------------------------------------------------------------------------
# 0       [CLS]               -13.019     .                   -2.677      -1
# 1       Person              -0.043      Person              -0.043      0
# 2       ##X                 -0.001      ##X                 -0.001      0
# 3       accidentally        -0.003      accidentally        -0.003      0
# 4       burned              -0.208      burned              -0.208      0
# 5       and                 -0.003      and                 -0.003      0
# 6       Person              -0.000      Person              -0.000      0
# 7       ##X                 -0.007      ##X                 -0.007      0
# 8       feels               -0.202      feels               -0.202      0
# 9       [MASK]              -15.228     guilty              -2.584      -1
# 10      .                   -0.000      .                   -0.000      0
# 11      [SEP]               -24.015     .                   -0.000      -1
#
#
# | Perplexity: 1.053
#
#
# *********************************
# EVENT: PersonX accidentally kicked and PersonX feels [MASK].
# GOLD: ('restless', 'embarrassed', 'guilty', 'sorry')
#
# | Top10 predictions
# 0       guilty              -2.545
# 1       bad                 -3.266
# 2       dizzy               -3.333
# 3       embarrassed         -3.350
# 4       hurt                -3.700
# 5       it                  -3.746
# 6       sick                -3.784
# 7       better              -3.814
# 8       defeated            -3.828
# 9       ashamed             -3.851
#
# ----------------------------------------------------------------------------------
# index   token               log_prob    prediction          log_prob    rank@1000
# ----------------------------------------------------------------------------------
# 0       [CLS]               -13.141     .                   -2.723      -1
# 1       Person              -0.188      Person              -0.188      0
# 2       ##X                 -0.001      ##X                 -0.001      0
# 3       accidentally        -0.001      accidentally        -0.001      0
# 4       kicked              -0.001      kicked              -0.001      0
# 5       and                 -0.004      and                 -0.004      0
# 6       Person              -0.000      Person              -0.000      0
# 7       ##X                 -0.009      ##X                 -0.009      0
# 8       feels               -0.661      feels               -0.661      0
# 9       [MASK]              -15.439     guilty              -2.545      -1
# 10      .                   -0.000      .                   -0.000      0
# 11      [SEP]               -23.902     .                   -0.000      -1
#
#
# | Perplexity: 1.101
#
#
# *********************************
# EVENT: PersonX accidently left and PersonX feels [MASK].
# GOLD: ('upset', 'unhappy', 'frustrated', 'confused', 'bad')
#
# | Top10 predictions
# 0       guilty              -1.587
# 1       bad                 -3.464
# 2       betrayed            -3.632
# 3       trapped             -3.749
# 4       defeated            -3.836
# 5       depressed           -3.877
# 6       lost                -3.883
# 7       better              -4.109
# 8       ashamed             -4.154
# 9       abandoned           -4.179
#
# ----------------------------------------------------------------------------------
# index   token               log_prob    prediction          log_prob    rank@1000
# ----------------------------------------------------------------------------------
# 0       [CLS]               -12.881     .                   -2.705      -1
# 1       Person              -0.018      Person              -0.018      0
# 2       ##X                 -0.001      ##X                 -0.001      0
# 3       accident            -0.001      accident            -0.001      0
# 4       ##ly                -0.000      ##ly                -0.000      0
# 5       left                -0.089      left                -0.089      0
# 6       and                 -0.002      and                 -0.002      0
# 7       Person              -0.000      Person              -0.000      0
# 8       ##X                 -0.006      ##X                 -0.006      0
# 9       feels               -0.026      feels               -0.026      0
# 10      [MASK]              -15.768     guilty              -1.587      -1
# 11      .                   -0.000      .                   -0.000      0
# 12      [SEP]               -24.014     .                   -0.000      -1
#
#
# | Perplexity: 1.014
#
#
# *********************************
# EVENT: PersonX accomplishes PersonY's work and PersonX feels [MASK].
# GOLD: ('satisfied',)
#
# | Top10 predictions
# 0       proud               -3.540
# 1       confident           -3.559
# 2       alive               -3.570
# 3       happy               -3.682
# 4       loved               -3.842
# 5       satisfied           -3.861
# 6       better              -3.862
# 7       good                -3.896
# 8       liberated           -3.922
# 9       powerful            -3.963
#
# ----------------------------------------------------------------------------------
# index   token               log_prob    prediction          log_prob    rank@1000
# ----------------------------------------------------------------------------------
# 0       [CLS]               -12.719     .                   -2.768      -1
# 1       Person              -0.007      Person              -0.007      0
# 2       ##X                 -0.000      ##X                 -0.000      0
# 3       accomplish          -0.000      accomplish          -0.000      0
# 4       ##es                -0.002      ##es                -0.002      0
# 5       Person              -0.000      Person              -0.000      0
# 6       ##Y                 -0.342      ##Y                 -0.342      0
# 7       '                   0.000       '                   0.000       0
# 8       s                   0.000       s                   0.000       0
# 9       work                -0.000      work                -0.000      0
# 10      and                 -0.000      and                 -0.000      0
# 11      Person              -0.000      Person              -0.000      0
# 12      ##X                 -0.001      ##X                 -0.001      0
# 13      feels               -0.003      feels               -0.003      0
# 14      [MASK]              -16.022     proud               -3.540      -1
# 15      .                   -0.000      .                   -0.000      0
# 16      [SEP]               -25.363     .                   -0.000      -1
#
#
# | Perplexity: 1.026
#
#
# *********************************
# EVENT: PersonX acts like a man and PersonX feels [MASK].
# GOLD: ('tough', 'good', 'mature', 'nervous')
#
# | Top10 predictions
# 0       good                -3.491
# 1       it                  -3.627
# 2       guilty              -3.779
# 3       confident           -3.782
# 4       happy               -3.786
# 5       bad                 -3.883
# 6       jealous             -3.946
# 7       threatened          -3.968
# 8       nothing             -4.010
# 9       betrayed            -4.015
#
# ----------------------------------------------------------------------------------
# index   token               log_prob    prediction          log_prob    rank@1000
# ----------------------------------------------------------------------------------
# 0       [CLS]               -13.034     .                   -2.662      -1
# 1       Person              -0.012      Person              -0.012      0
# 2       ##X                 -0.002      ##X                 -0.002      0
# 3       acts                -0.000      acts                -0.000      0
# 4       like                -0.000      like                -0.000      0
# 5       a                   -0.000      a                   -0.000      0
# 6       man                 -0.001      man                 -0.001      0
# 7       and                 -0.000      and                 -0.000      0
# 8       Person              -0.000      Person              -0.000      0
# 9       ##X                 -0.019      ##X                 -0.019      0
# 10      feels               -0.010      feels               -0.010      0
# 11      [MASK]              -14.840     good                -3.491      -1
# 12      .                   -0.000      .                   -0.000      0
# 13      [SEP]               -26.620     .                   -0.000      -1
#
#
# | Perplexity: 1.004
#
#
# *********************************
# EVENT: PersonX adds insult to injury and PersonX feels [MASK].
# GOLD: ('happy',)
#
# | Top10 predictions
# 0       guilty              -3.142
# 1       better              -3.312
# 2       good                -3.642
# 3       bad                 -3.891
# 4       ashamed             -3.905
# 5       proud               -3.994
# 6       defeated            -4.151
# 7       safe                -4.187
# 8       threatened          -4.223
# 9       victorious          -4.267
#
# ----------------------------------------------------------------------------------
# index   token               log_prob    prediction          log_prob    rank@1000
# ----------------------------------------------------------------------------------
# 0       [CLS]               -12.852     .                   -2.637      -1
# 1       Person              -0.049      Person              -0.049      0
# 2       ##X                 -0.001      ##X                 -0.001      0
# 3       adds                -0.001      adds                -0.001      0
# 4       insult              -0.010      insult              -0.010      0
# 5       to                  -0.000      to                  -0.000      0
# 6       injury              -0.009      injury              -0.009      0
# 7       and                 -0.001      and                 -0.001      0
# 8       Person              -0.000      Person              -0.000      0
# 9       ##X                 -0.004      ##X                 -0.004      0
# 10      feels               -0.004      feels               -0.004      0
# 11      [MASK]              -15.252     guilty              -3.142      -1
# 12      .                   -0.000      .                   -0.000      0
# 13      [SEP]               -25.029     .                   -0.000      -1
#
#
# | Perplexity: 1.007
#
#
# *********************************
# EVENT: PersonX adopts a baby and PersonX feels [MASK].
# GOLD: ('responsible', 'caring', 'tearful', 'loving', 'excited')
#
# | Top10 predictions
# 0       happy               -2.337
# 1       safe                -2.887
# 2       lonely              -3.337
# 3       better              -3.478
# 4       guilty              -3.527
# 5       loved               -3.627
# 6       depressed           -3.650
# 7       abandoned           -3.731
# 8       responsible         -4.008
# 9       threatened          -4.100
#
# ----------------------------------------------------------------------------------
# index   token               log_prob    prediction          log_prob    rank@1000
# ----------------------------------------------------------------------------------
# 0       [CLS]               -12.721     .                   -2.785      -1
# 1       Person              -0.027      Person              -0.027      0
# 2       ##X                 -0.001      ##X                 -0.001      0
# 3       adopt               -0.000      adopt               -0.000      0
# 4       ##s                 -0.000      ##s                 -0.000      0
# 5       a                   -0.000      a                   -0.000      0
# 6       baby                -0.005      baby                -0.005      0
# 7       and                 -0.000      and                 -0.000      0
# 8       Person              -0.000      Person              -0.000      0
# 9       ##X                 -0.007      ##X                 -0.007      0
# 10      feels               -0.004      feels               -0.004      0
# 11      [MASK]              -15.510     happy               -2.337      -1
# 12      .                   -0.000      .                   -0.000      0
# 13      [SEP]               -26.592     .                   -0.000      -1
#
#
# | Perplexity: 1.004
#
#
# *********************************
# EVENT: PersonX adopts the kitten and PersonX feels [MASK].
# GOLD: ('nurturing', 'loving', 'caring', 'happy')
#
# | Top10 predictions
# 0       happy               -2.393
# 1       safe                -2.644
# 2       comfortable         -3.517
# 3       better              -3.629
# 4       threatened          -3.818
# 5       guilty              -3.901
# 6       it                  -3.977
# 7       abandoned           -4.059
# 8       uncomfortable       -4.091
# 9       responsible         -4.129
#
# ----------------------------------------------------------------------------------
# index   token               log_prob    prediction          log_prob    rank@1000
# ----------------------------------------------------------------------------------
# 0       [CLS]               -12.832     .                   -2.821      -1
# 1       Person              -0.042      Person              -0.042      0
# 2       ##X                 -0.002      ##X                 -0.002      0
# 3       adopt               -0.004      adopt               -0.004      0
# 4       ##s                 -0.000      ##s                 -0.000      0
# 5       the                 -0.000      the                 -0.000      0
# 6       kit                 -0.000      kit                 -0.000      0
# 7       ##ten               -0.000      ##ten               -0.000      0
# 8       and                 -0.000      and                 -0.000      0
# 9       Person              -0.000      Person              -0.000      0
# 10      ##X                 -0.011      ##X                 -0.011      0
# 11      feels               -0.007      feels               -0.007      0
# 12      [MASK]              -15.189     happy               -2.393      -1
# 13      .                   -0.000      .                   -0.000      0
# 14      [SEP]               -24.898     .                   -0.000      -1
#
#
# | Perplexity: 1.006
#
#
# *********************************
# EVENT: PersonX advances toward PersonY and PersonX feels [MASK].
# GOLD: ('talkative', 'frisky', 'angry', 'happy')
#
# | Top10 predictions
# 0       threatened          -2.870
# 1       defeated            -2.883
# 2       betrayed            -3.339
# 3       uncomfortable       -3.737
# 4       trapped             -3.794
# 5       it                  -3.805
# 6       guilty              -3.950
# 7       jealous             -4.144
# 8       lost                -4.311
# 9       victorious          -4.389
#
# ----------------------------------------------------------------------------------
# index   token               log_prob    prediction          log_prob    rank@1000
# ----------------------------------------------------------------------------------
# 0       [CLS]               -12.730     .                   -2.656      -1
# 1       Person              -0.018      Person              -0.018      0
# 2       ##X                 -0.001      ##X                 -0.001      0
# 3       advances            -0.001      advances            -0.001      0
# 4       toward              -0.052      toward              -0.052      0
# 5       Person              -0.000      Person              -0.000      0
# 6       ##Y                 -0.277      ##Y                 -0.277      0
# 7       and                 -0.001      and                 -0.001      0
# 8       Person              -0.000      Person              -0.000      0
# 9       ##X                 -0.009      ##X                 -0.009      0
# 10      feels               -0.001      feels               -0.001      0
# 11      [MASK]              -15.176     threatened          -2.870      -1
# 12      .                   -0.000      .                   -0.000      0
# 13      [SEP]               -24.442     .                   -0.000      -1
#
#
# | Perplexity: 1.033
#
#
# *********************************
# EVENT: PersonX advises PersonY to go and PersonX feels [MASK].
# GOLD: ('happy', 'good', 'hurt', 'disappointed', 'satisfied')
#
# | Top10 predictions
# 0       guilty              -2.258
# 1       betrayed            -3.050
# 2       threatened          -3.297
# 3       defeated            -3.455
# 4       uncomfortable       -3.481
# 5       bad                 -3.528
# 6       relieved            -3.624
# 7       rejected            -3.701
# 8       disappointed        -4.042
# 9       better              -4.080
#
# ----------------------------------------------------------------------------------
# index   token               log_prob    prediction          log_prob    rank@1000
# ----------------------------------------------------------------------------------
# 0       [CLS]               -12.877     .                   -2.663      -1
# 1       Person              -0.011      Person              -0.011      0
# 2       ##X                 -0.001      ##X                 -0.001      0
# 3       advise              -0.000      advise              -0.000      0
# 4       ##s                 -0.000      ##s                 -0.000      0
# 5       Person              -0.000      Person              -0.000      0
# 6       ##Y                 -0.337      ##Y                 -0.337      0
# 7       to                  -0.000      to                  -0.000      0
# 8       go                  -0.000      go                  -0.000      0
# 9       and                 -0.001      and                 -0.001      0
# 10      Person              -0.000      Person              -0.000      0
# 11      ##X                 -0.004      ##X                 -0.004      0
# 12      feels               -0.005      feels               -0.005      0
# 13      [MASK]              -15.435     guilty              -2.258      -1
# 14      .                   -0.000      .                   -0.000      0
# 15      [SEP]               -26.407     .                   -0.000      -1
#
#
# | Perplexity: 1.028
#
#
# *********************************
# EVENT: PersonX affords college and PersonX feels [MASK].
# GOLD: ('successful',)
#
# | Top10 predictions
# 0       happy               -2.780
# 1       rich                -2.972
# 2       lonely              -2.981
# 3       depressed           -3.528
# 4       good                -3.783
# 5       free                -4.008
# 6       safe                -4.026
# 7       confident           -4.042
# 8       privileged          -4.051
# 9       better              -4.097
#
# ----------------------------------------------------------------------------------
# index   token               log_prob    prediction          log_prob    rank@1000
# ----------------------------------------------------------------------------------
# 0       [CLS]               -12.688     .                   -2.723      -1
# 1       Person              -0.054      Person              -0.054      0
# 2       ##X                 -0.009      ##X                 -0.009      0
# 3       afford              -0.010      afford              -0.010      0
# 4       ##s                 -0.000      ##s                 -0.000      0
# 5       college             -0.038      college             -0.038      0
# 6       and                 -0.000      and                 -0.000      0
# 7       Person              -0.001      Person              -0.001      0
# 8       ##X                 -0.012      ##X                 -0.012      0
# 9       feels               -0.001      feels               -0.001      0
# 10      [MASK]              -15.958     happy               -2.780      -1
# 11      .                   -0.000      .                   -0.000      0
# 12      [SEP]               -27.624     .                   -0.000      -1
#
#
# | Perplexity: 1.013
#
#
# *********************************

# %% [markdown]
# # Statistics

# %%
df, dataset = create_dataset('data/test.csv')
df.emotion = df.emotion.apply(lambda x: len(x))
